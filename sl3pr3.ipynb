# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejas9523/DataScienceLab/blob/main/sl3pr3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Create dataset
np.random.seed(0)
data = {
 'Age': np.random.randint(20, 60, size=100), # Generate random age between 20 and 60
 'Income': np.random.randint(30000, 100000, size=100), # Generate random income between 30,000 and 100,000
 'Gender': np.random.choice(['Male', 'Female'], size=100) # Randomly assign gender
}
# Convert dictionary to DataFrame
df = pd.DataFrame(data)
# Convert DataFrame to CSV file
df.to_csv('dataset.csv', index=False)
df.head()
# Out:
#    Age  Income  Gender
# 0   20   54777  Female
# 1   23   43824  Female
# 2   23   32418    Male
# 3   59   42843  Female
# 4   29   66223    Male

# %%
# Summary statistics grouped by Gender
summary_stats = df.groupby('Gender').describe()
summary_stats
# Out:
#          Age                                                     Income  \
#        count       mean        std   min   25%   50%   75%   max  count
# Gender
# Female  55.0  40.000000  13.011391  20.0  31.5  39.0  53.0  59.0   55.0
# Male    45.0  37.688889  12.341398  20.0  26.0  36.0  49.0  59.0   45.0
#
#                                                                         \
#                 mean           std      min      25%      50%      75%
# Gender
# Female  63817.400000  20711.080831  30469.0  45766.0  63538.0  76373.5
# Male    62849.488889  19970.093965  30894.0  45588.0  65489.0  80586.0
#
#
#             max
# Gender
# Female  99939.0
# Male    95180.0

# %%
# Create a dictionary to map categorical values to numeric values
category_mapping = {'Male': 0, 'Female': 1}
# Map the categorical variable 'Gender' to numeric values
numeric_gender = df['Gender'].map(category_mapping)
# Display the numeric values for each response to the categorical variable
numeric_gender
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     0
#      ..
# 95    1
# 96    0
# 97    0
# 98    1
# 99    0
# Name: Gender, Length: 100, dtype: int64

# %%
import pandas as pd
# Load the iris dataset
iris_df = pd.read_csv("/content/Iris.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Check the data types of all columns
print(iris_df.dtypes)
# Convert the numeric columns to numeric data type
numeric_columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
'PetalWidthCm']
iris_df[numeric_columns] = iris_df[numeric_columns].apply(pd.to_numeric, errors='coerce')
# Check the data types again after conversion
print(iris_df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Filter out numeric columns
numeric_cols = iris_df.select_dtypes(include=np.number)
# Display percentile, mean, standard deviation, etc. for numeric columns
print("\nPercentile (25%):")
print(numeric_cols.quantile(0.25))
print("\nMean:")
print(numeric_cols.mean())
print("\nStandard Deviation:")
print(numeric_cols.std())
# Add other statistical measures as needed
# Out:
# Percentile (25%):
# Id               38.25
# SepalLengthCm     5.10
# SepalWidthCm      2.80
# PetalLengthCm     1.60
# PetalWidthCm      0.30
# Name: 0.25, dtype: float64
#
# Mean:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64
#
# Standard Deviation:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
# Calculate minimum
print("\nMinimum:")
print(iris_df.min())
# Calculate maximum
print("\nMaximum:")
print(iris_df.max())
# Out:
# Minimum:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object
#
# Maximum:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object
